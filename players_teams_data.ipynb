# %% [markdown]
# # Import modules

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import requests
from bs4 import BeautifulSoup
import copy
import time
from collections import Counter
from fuzzywuzzy import fuzz

# %%
from nba_api.stats.static import players, teams
from nba_api.stats.endpoints import commonplayerinfo, playercareerstats, commonallplayers

# %% [markdown]
# # Team Data

# %%
data_teams = pd.DataFrame(teams.get_teams())
data_teams.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Atlanta          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %%
data_teams.to_csv('teams_data.csv', index = False)

# %% [markdown]
# ### Team Salaries

# %%
years = {'2021/22': '', '2022/23': '2022', '2023/24': '2023', '2024/25': '2024'}

for y in years.keys():
    
    url = 'https://www.spotrac.com/nba/cap/' + years[y]
    r = requests.get(url, timeout=2.5)
    r_html = r.text
    soup = BeautifulSoup(r_html, 'html.parser')

    salary_table = soup.find('table')
    
    if y == '2021/22':
        cap_space = [[salary_table.find_all("td")[i].text.strip() for i in [(j-1)*12+1, (j-1)*12+9]] for j in range(1, 31)]
        salary_cap_teams = pd.DataFrame(cap_space, columns=['Team', y])
        print(y)
        continue
    else:
        cap_space = [[salary_table.find_all("td")[i].text.strip() for i in [(j-1)*11+1, (j-1)*11+8]] for j in range(1, 31)]
        print(y)
    
    
    salary_cap_year = pd.DataFrame(cap_space, columns=['Team', y])
    
    salary_cap_teams = salary_cap_teams.merge(salary_cap_year, on = 'Team', how = 'left')
# Out:
# 2021/22
# 2022/23
# 2023/24
# 2024/25

# %%
salary_cap_teams.insert(1, 'Abb', salary_cap_teams['Team'].str[-3:])
salary_cap_teams['Team'] = salary_cap_teams['Team'].str[:-3]
salary_cap_teams.insert(0, 'Team_ID', [list(data_teams[data_teams['full_name'] == salary_cap_teams['Team'][i]]['id'])[0] for i in range(salary_cap_teams.shape[0])])

# lakers in 2021: -50 mil -> 50 mil over Cap

# %%
for col in salary_cap_teams.columns[3:]:
    salary_cap_teams[col] = salary_cap_teams[col].apply(lambda x: x.replace('$', '').replace(',', '')).astype(float)
        
salary_cap_teams
# Out:
#        Team_ID                    Team  Abb     2021/22     2022/23  \
# 0   1610612760   Oklahoma City Thunder  OKC  24572406.0  -1848998.0
# 1   1610612763       Memphis Grizzlies  MEM  -3347775.0 -15442836.0
# 2   1610612740    New Orleans Pelicans  NOP  -4004104.0 -15614516.0
# 3   1610612766       Charlotte Hornets  CHA  -4490105.0 -18232263.0
# 4   1610612752         New York Knicks  NYK  -5042436.0 -18174322.0
# 5   1610612759       San Antonio Spurs  SAS  -5498958.0  -5657182.0
# 6   1610612765         Detroit Pistons  DET -12756440.0  19834484.0
# 7   1610612756            Phoenix Suns  PHX -15959873.0 -54333058.0
# 8   1610612745         Houston Rockets  HOU -17647614.0 -21705994.0
# 9   1610612753           Orlando Magic  ORL -18026594.0 -49345552.0
# 10  1610612741           Chicago Bulls  CHI -20969107.0 -43463461.0
# 11  1610612758        Sacramento Kings  SAC -21117597.0 -36642611.0
# 12  1610612737           Atlanta Hawks  ATL -22318348.0 -71986412.0
# 13  1610612739     Cleveland Cavaliers  CLE -22598282.0 -40650498.0
# 14  1610612754          Indiana Pacers  IND -24446451.0 -34693067.0
# 15  1610612743          Denver Nuggets  DEN -26132894.0 -61097805.0
# 16  1610612748              Miami Heat  MIA -27093802.0 -61761522.0
# 17  1610612742        Dallas Mavericks  DAL -29511625.0 -42578509.0
# 18  1610612738          Boston Celtics  BOS -30511171.0 -48413751.0
# 19  1610612757  Portland Trail Blazers  POR -35811444.0 -60851181.0
# 20  1610612761         Toronto Raptors  TOR -39674929.0 -33470058.0
# 21  1610612755      Philadelphia 76ers  PHI -43190339.0 -37657054.0
# 22  1610612762               Utah Jazz  UTH -43972587.0 -59623529.0
# 23  1610612749         Milwaukee Bucks  MIL -44790900.0 -60471340.0
# 24  1610612764      Washington Wizards  WAS -51994133.0 -78505300.0
# 25  1610612750  Minnesota Timberwolves  MIN -52947475.0 -80349808.0
# 26  1610612747      Los Angeles Lakers  LAL -52961931.0 -53987571.0
# 27  1610612746    Los Angeles Clippers  LAC -57734478.0 -67560501.0
# 28  1610612751           Brooklyn Nets  BKN -64709073.0 -66427699.0
# 29  1610612744   Golden State Warriors  GSW -71610649.0 -87008345.0
#
#        2023/24     2024/25
# 0   -9418667.0  41399666.0
# 1  -30850268.0  57216487.0
# 2  -45768872.0  -7268819.0
# 3  -20502290.0   8171964.0
# 4  -35439037.0 -22895991.0
# 5    6625794.0  23360149.0
# 6    8496824.0  34931858.0
# 7  -53905519.0   5154000.0
# 8  -37760728.0  44214930.0
# 9   -8848482.0 -22092877.0
# 10 -16350122.0  21665889.0
# 11 -23636716.0  23659142.0
# 12 -87169221.0 -29869916.0
# 13 -37903251.0  52058312.0
# 14 -32680211.0  85525023.0
# 15 -79710735.0  -5203626.0
# 16 -47933862.0 -23713757.0
# 17 -45004909.0   -173266.0
# 18 -89733771.0  -6894000.0
# 19 -20108842.0   7814038.0
# 20 -23487022.0 -68202305.0
# 21 -80038222.0 -34914752.0
# 22 -48590984.0 -52977944.0
# 23 -69099482.0 -26087549.0
# 24 -70143722.0  21723384.0
# 25 -34941401.0 -36516621.0
# 26 -50806185.0  66009095.0
# 27 -95045760.0 -31415422.0
# 28 -67894955.0  36656286.0
# 29 -91761574.0 -66656438.0

# %%
salary_cap_teams.to_csv('teams_salaries.csv', index = False)

# %% [markdown]
# # Players

# %% [markdown]
# ### Player salaries

# %%
url='https://hoopshype.com/salaries/players/'

r = requests.get(url, timeout=2.5)
r_html = r.text

soup = BeautifulSoup(r_html, 'html.parser')

salary_table = soup.find('table')

# %%
length=len(salary_table.find_all("td"))

player_names=[salary_table.find_all("td")[i].text.strip() for i in range(9,length,8)]

column1=[salary_table.find_all("td")[i].text.strip() for i in range(10,length,8)]
column2=[salary_table.find_all("td")[i].text.strip() for i in range(11,length,8)]
column3=[salary_table.find_all("td")[i].text.strip() for i in range(12,length,8)]
column4=[salary_table.find_all("td")[i].text.strip() for i in range(13,length,8)]
column5=[salary_table.find_all("td")[i].text.strip() for i in range(14,length,8)]
column6=[salary_table.find_all("td")[i].text.strip() for i in range(15,length,8)]

# %%
dict_df = {'player_names':player_names,
         # '2019/20':column1,
         # '2020/21':column2,
          '2021/22':column3,
          '2022/23':column4,
          '2023/24':column5,
          '20124/25':column6}
        
player_salary = pd.DataFrame(dict_df)

# %%
player_salary
# Out:
#           player_names      2021/22      2022/23      2023/24 20124/25
# 0        Stephen Curry  $51,915,615  $55,761,217  $59,606,817       $0
# 1         James Harden           $0           $0           $0       $0
# 2            John Wall           $0           $0           $0       $0
# 3    Russell Westbrook           $0           $0           $0       $0
# 4         LeBron James           $0           $0           $0       $0
# ..                 ...          ...          ...          ...      ...
# 531  Admiral Schofield           $0           $0           $0       $0
# 532      Troy Williams           $0           $0           $0       $0
# 533     Mamadi Diakite           $0           $0           $0       $0
# 534  Demetrius Jackson      $92,857           $0           $0       $0
# 535  Freddie Gillespie           $0           $0           $0       $0
#
# [536 rows x 5 columns]

# %%
player_salary = player_salary.rename(columns={"20124/25": "2024/25"})

# %%
salary_years = ['2021/22', '2022/23', '2023/24', '2024/25']

# %%
for col in salary_years:
    player_salary[col] = player_salary[col].apply(lambda x: x.replace('$', '').replace(',', '')).astype(float)
    
    
# + also discount as in scratchpad.ipynb to get NPV?

# %% [markdown]
# ## Match players from NBA API to Salaries -> get Player-IDs

# %%
response = commonallplayers.CommonAllPlayers(is_only_current_season = ['0'],season=['2021']).get_data_frames()[0] # get all players & indicate current season for rosterstatus
response_new = response[(response['ROSTERSTATUS'] == 1) # get active players -> players who retired at end of last season are not contained (e.g. 'JJ Redick')
                        & ((response['FROM_YEAR'] != '2021')) # no current rookies
                       ].reset_index()
print(response_new.shape)
# Out:
# (418, 17)

# %%
# match players from salary table and from nba table to get unique IDs

player_ids = []
player_names = [list(response_new['DISPLAY_FIRST_LAST'])[j] for j in range(response_new.shape[0])]
player_names.append('unk') # such that list 
for i in range(player_salary.shape[0]):
    player_name = player_salary['player_names'][i]
    try:
        player_ids.append(list(response_new[response_new['DISPLAY_FIRST_LAST'] == player_name]['PERSON_ID'])[0])
        try:
            player_names.remove(player_name)
        except ValueError:
            print('Here', player_name)
        
    except IndexError:
        player_ids.append(0)

for i in range(len(player_ids)):
    if player_ids[i] == 0:
        player_name = player_salary['player_names'][i]
        fuzz_scores = np.array([fuzz.ratio(player_name, player_names[j]) for j in range(len(player_names))])
        max_ind = np.argmax(fuzz_scores)
        if fuzz_scores[max_ind] > 65:
            matched_player_name = player_names[max_ind] #list(response_new['DISPLAY_FIRST_LAST'])[max_ind]
            print(f"{player_name} matched to {matched_player_name}")
            player_ids[i] = list(response_new[response_new['DISPLAY_FIRST_LAST'] == matched_player_name]['PERSON_ID'])[0]
            player_names.remove(matched_player_name)
        else:
            #player_ids.append(0)
            print(f"{player_name} NOT matched to {player_names[max_ind]}")

print(player_names)
# Out:
# Tim Hardaway Jr matched to Tim Hardaway Jr.
# Gary Trent Jr matched to Gary Trent Jr.
# Marcus Morris matched to Marcus Morris Sr.
# TJ Warren matched to T.J. Warren
# Kelly Oubre matched to Kelly Oubre Jr.
# Marvin Bagley matched to Marvin Bagley III
# Devonte Graham matched to Devonte' Graham
# Larry Nance Jr matched to Larry Nance Jr.
# Al-Farouq Aminu NOT matched to Nic Claxton
# Cade Cunningham NOT matched to Juancho Hernangomez
# Derrick Jones matched to Derrick Jones Jr.
# Jaren Jackson Jr matched to Jaren Jackson Jr.
# Jalen Green NOT matched to Juancho Hernangomez
# Evan Mobley NOT matched to Danuel House Jr.
# TJ McConnell matched to T.J. McConnell
# Scottie Barnes NOT matched to Maurice Harkless
# PJ Tucker matched to P.J. Tucker
# DJ Augustin matched to D.J. Augustin
# Wendell Carter matched to Wendell Carter Jr.
# Juan Hernangomez matched to Juancho Hernangomez
# Jalen Suggs NOT matched to Danuel House Jr.
# Joakim Noah NOT matched to R.J. Hampton
# Josh Giddey NOT matched to Ish Smith
# Patrick Mills matched to Patty Mills
# Dennis Schroeder matched to Dennis Schroder
# Kevin Knox matched to Kevin Knox II
# Timofey Mozgov NOT matched to Timothe Luwawu-Cabarrot
# Jonathan Kuminga NOT matched to P.J. Washington
# Michael Porter matched to Michael Porter Jr.
# Ryan Anderson NOT matched to Troy Brown Jr.
# Troy Brown matched to Troy Brown Jr.
# Franz Wagner NOT matched to Vernon Carey Jr.
# Kris Dunn NOT matched to Kira Lewis Jr.
# Louis Williams matched to Lou Williams
# Luol Deng NOT matched to unk
# Davion Mitchell NOT matched to Svi Mykhailiuk
# Ishmael Smith matched to Ish Smith
# Lonnie Walker matched to Lonnie Walker IV
# Ziaire Williams NOT matched to Robert Williams III
# Moe Harkless matched to Maurice Harkless
# PJ Washington matched to P.J. Washington
# James Bouknight NOT matched to R.J. Hampton
# Josh Primo NOT matched to R.J. Hampton
# Danuel House matched to Danuel House Jr.
# Kira Lewis matched to Kira Lewis Jr.
# Chris Duarte NOT matched to Vernon Carey Jr.
# Sekou Doumbouya NOT matched to DeAndre' Bembry
# Robert Williams matched to Robert Williams III
# Moses Moody NOT matched to Robert Woodard II
# Corey Kispert NOT matched to Vernon Carey Jr.
# Alperen Sengun NOT matched to DeAndre' Bembry
# Jon Leuer NOT matched to Vernon Carey Jr.
# Trey Murphy NOT matched to DeAndre' Bembry
# Tre Mann NOT matched to Kenyon Martin Jr.
# Andrew Nicholson NOT matched to Nic Claxton
# Kai Jones NOT matched to Nic Claxton
# Marc Gasol NOT matched to Nic Claxton
# Jalen Johnson NOT matched to Kenyon Martin Jr.
# Keon Johnson NOT matched to Kenyon Martin Jr.
# Isaiah Jackson NOT matched to Nic Claxton
# Otto Porter matched to Otto Porter Jr.
# Usman Garuba NOT matched to Timothe Luwawu-Cabarrot
# Leandro Bolmaro NOT matched to DeAndre' Bembry
# Edmond Sumner NOT matched to DeAndre' Bembry
# RJ Hampton matched to R.J. Hampton
# Josh Christopher NOT matched to Vernon Carey Jr.
# Monta Ellis NOT matched to Svi Mykhailiuk
# Quentin Grimes NOT matched to Kenyon Martin Jr.
# Jahlil Okafor NOT matched to Nic Claxton
# Bones Hyland NOT matched to Nic Claxton
# Cam Thomas NOT matched to Nic Claxton
# Jaden Springer NOT matched to Kenyon Martin Jr.
# Day'Ron Sharpe NOT matched to Vernon Carey Jr.
# Jeremiah Robinson-Earl NOT matched to Vernon Carey Jr.
# Santiago Aldama NOT matched to Nic Claxton
# Timothe Luwawu matched to Timothe Luwawu-Cabarrot
# PJ Dozier matched to P.J. Dozier
# Larry Sanders NOT matched to Vernon Carey Jr.
# Wesley Iwundu NOT matched to Vernon Carey Jr.
# Dennis Smith matched to Dennis Smith Jr.
# Kevin Porter matched to Kevin Porter Jr.
# Nicolas Claxton matched to Nic Claxton
# Carsen Edwards NOT matched to Vernon Carey Jr.
# Sviatoslav Mykhailiuk matched to Svi Mykhailiuk
# Herb Jones NOT matched to Vernon Carey Jr.
# Kevin Pangos NOT matched to Kenyon Martin Jr.
# DeAndre Bembry matched to DeAndre' Bembry
# Vernon Carey matched to Vernon Carey Jr.
# Tyrell Terry NOT matched to Kenyon Martin Jr.
# KJ Martin NOT matched to Kenyon Martin Jr.
# Robert Woodard matched to Robert Woodard II
# Deividas Sirvydis NOT matched to Kenyon Martin Jr.
# Daniel Oturu NOT matched to Kenyon Martin Jr.
# Isaiah Todd NOT matched to Kenyon Martin Jr.
# JR Smith NOT matched to Kenyon Martin Jr.
# JT Thor NOT matched to Kenyon Martin Jr.
# DeMarre Carroll NOT matched to Kenyon Martin Jr.
# Zhaire Smith NOT matched to Kenyon Martin Jr.
# Jason Preston NOT matched to Kenyon Martin Jr.
# Isaiah Livers NOT matched to Kenyon Martin Jr.
# Guerschon Yabusele NOT matched to Kenyon Martin Jr.
# Kyle Singler NOT matched to Kenyon Martin Jr.
# BJ Boston NOT matched to Kenyon Martin Jr.
# Austin Reaves NOT matched to Kenyon Martin Jr.
# Georgios Kalaitzakis NOT matched to Kenyon Martin Jr.
# Miles McBride NOT matched to Kenyon Martin Jr.
# Vit Krejci NOT matched to Kenyon Martin Jr.
# Charles Bassey NOT matched to Kenyon Martin Jr.
# Greg Brown NOT matched to Kenyon Martin Jr.
# Jock Landale NOT matched to Kenyon Martin Jr.
# Jared Butler NOT matched to Kenyon Martin Jr.
# Ayo Dosunmu NOT matched to Kenyon Martin Jr.
# Marko Simonovic NOT matched to Kenyon Martin Jr.
# Luka Garza NOT matched to unk
# Dalano Banton NOT matched to Kenyon Martin Jr.
# Patrick Patterson NOT matched to Kenyon Martin Jr.
# Ishmail Wainright NOT matched to Kenyon Martin Jr.
# Shaun Livingston NOT matched to Kenyon Martin Jr.
# Sharife Cooper NOT matched to Kenyon Martin Jr.
# Sam Hauser NOT matched to Kenyon Martin Jr.
# David Duke NOT matched to unk
# Kessler Edwards NOT matched to Kenyon Martin Jr.
# Arnoldas Kulboka NOT matched to Kenyon Martin Jr.
# Scottie Lewis NOT matched to Kenyon Martin Jr.
# RJ Nembhard NOT matched to Kenyon Martin Jr.
# JaQuori McLaughlin NOT matched to Kenyon Martin Jr.
# Eugene Omoruyi NOT matched to Kenyon Martin Jr.
# Petr Cornelie NOT matched to Kenyon Martin Jr.
# Jamorko Pickett NOT matched to Kenyon Martin Jr.
# Sean Chris Smith NOT matched to Kenyon Martin Jr.
# Jeff Dowtin NOT matched to Kenyon Martin Jr.
# Daishen Nix NOT matched to Kenyon Martin Jr.
# DeJon Jarreau NOT matched to Kenyon Martin Jr.
# Duane Washington Jr NOT matched to Kenyon Martin Jr.
# Jay Huff NOT matched to unk
# Yves Pons NOT matched to Kenyon Martin Jr.
# Marcus Garrett NOT matched to Kenyon Martin Jr.
# Sandro Mamukelashvili NOT matched to Kenyon Martin Jr.
# McKinley Wright NOT matched to Kenyon Martin Jr.
# Jose Alvarado NOT matched to Kenyon Martin Jr.
# Daulton Hommes NOT matched to Kenyon Martin Jr.
# Jericho Sims NOT matched to Kenyon Martin Jr.
# Aaron Wiggins NOT matched to Kenyon Martin Jr.
# Aaron Henry NOT matched to Kenyon Martin Jr.
# Trendon Watford NOT matched to Kenyon Martin Jr.
# Neemias Queta NOT matched to Kenyon Martin Jr.
# Joe Wieskamp NOT matched to Kenyon Martin Jr.
# Justin Champagnie NOT matched to Kenyon Martin Jr.
# David Johnson NOT matched to Kenyon Martin Jr.
# Joel Ayayi NOT matched to Kenyon Martin Jr.
# Chaundee Brown NOT matched to Kenyon Martin Jr.
# Sam Dekker NOT matched to Kenyon Martin Jr.
# Jontay Porter NOT matched to Kenyon Martin Jr.
# Admiral Schofield NOT matched to Kenyon Martin Jr.
# Troy Williams NOT matched to Kenyon Martin Jr.
# Mamadi Diakite NOT matched to Kenyon Martin Jr.
# Demetrius Jackson NOT matched to Kenyon Martin Jr.
# Freddie Gillespie NOT matched to Kenyon Martin Jr.
# ['Kenyon Martin Jr.', 'unk']

# %%
further_player_ids = []
for i in range(len(player_names)-1):
    player_name = player_names[i]
    fuzz_scores = np.array([fuzz.ratio(player_name, list(player_salary['player_names'])[j]) for j in range(player_salary.shape[0])])
    max_ind = np.argpartition(fuzz_scores, -3)[-3:]
    possbile_matches = player_salary['player_names'][max_ind].reset_index(drop = True) #list(response_new['DISPLAY_FIRST_LAST'])[max_ind]
    print(f"{player_name} could be matched to the following 3 players\n{possbile_matches}")
    matched_id = int(input('Which player should be chosen (please indicate the index)?\n'))
    further_player_ids.append(possbile_matches[matched_id])
    print(f"Added {possbile_matches[matched_id]} for {player_name}")
    
    # Kenyon Martin Jr. -> KJ Martin
# Out:
# Kenyon Martin Jr. could be matched to the following 3 players
# 0     Cody Martin
# 1       KJ Martin
# 2    Kelan Martin
# Name: player_names, dtype: object
# Which player should be chosen (please indicate the index)?
# 1
# Added KJ Martin for Kenyon Martin Jr.

# %%
for i in range(len(further_player_ids)):
    idx_matched_player = player_salary.index[player_salary['player_names'] == further_player_ids[0]].to_list()[0]
    player_ids[idx_matched_player] = list(response_new[response_new['DISPLAY_FIRST_LAST'] == player_names[i]]['PERSON_ID'])[0]
    
# player_ids[428] = list(response_new[response_new['DISPLAY_FIRST_LAST'] == player_names[0]]['PERSON_ID'])[0] # Kenyon Martin Jr. -> KJ Martin

# %%
player_salary.insert(0, "id", player_ids)

# %%
# players which could not be matched, but have salary in current seasons: rookies

player_salary[(player_salary['id'] == 0) & (player_salary['2021/22'] != 0)]
# Out:
#      id            player_names     2021/22     2022/23     2023/24  2024/25
# 126   0         Cade Cunningham  11055360.0  13940809.0  18123052.0      0.0
# 143   0             Jalen Green   9891480.0  12483048.0  16290377.0      0.0
# 162   0             Evan Mobley   8882640.0  11227657.0  14730686.0      0.0
# 170   0          Scottie Barnes   8008680.0  10130980.0  13362763.0      0.0
# 179   0             Jalen Suggs   7252080.0   9188385.0  12183799.0      0.0
# 187   0             Josh Giddey   6587040.0   8352367.0  11142057.0      0.0
# 197   0        Jonathan Kuminga   6012840.0   7636307.0  10240287.0      0.0
# 209   0            Franz Wagner   5508720.0   7007092.0   9445560.0      0.0
# 227   0         Davion Mitchell   5063640.0   6451077.0   8741210.0      0.0
# 235   0         Ziaire Williams   4810200.0   6133005.0   8353152.0      0.0
# 241   0         James Bouknight   4570080.0   6064496.0   8302295.0      0.0
# 252   0              Josh Primo   4341600.0   5982725.0   8232229.0      0.0
# 260   0            Chris Duarte   4124400.0   5893768.0   8151081.0      0.0
# 267   0             Moses Moody   3918480.0   5803269.0   8072347.0      0.0
# 272   0           Corey Kispert   3722040.0   5705887.0   7976830.0      0.0
# 278   0          Alperen Sengun   3536280.0   5424654.0   7621638.0      0.0
# 284   0             Trey Murphy   3359280.0   5159854.0   7285713.0      0.0
# 288   0                Tre Mann   3191400.0   4908373.0   6964982.0      0.0
# 292   0               Kai Jones   3047880.0   4693735.0   6693266.0      0.0
# 296   0           Jalen Johnson   2925360.0   4510905.0   6464127.0      0.0
# 313   0            Keon Johnson   2808720.0   4474291.0   6447453.0      0.0
# 317   0          Isaiah Jackson   2696280.0   4435380.0   6422431.0      0.0
# 329   0            Usman Garuba   2588400.0   4392515.0   6391109.0      0.0
# 330   0         Leandro Bolmaro   2588400.0   4392515.0   6391109.0      0.0
# 336   0        Josh Christopher   2485200.0   4346615.0   6354751.0      0.0
# 343   0          Quentin Grimes   2385720.0   4296682.0   6311825.0      0.0
# 349   0            Bones Hyland   2306400.0   4158439.0   6137856.0      0.0
# 356   0              Cam Thomas   2240160.0   4041249.0   5993172.0      0.0
# 358   0          Jaden Springer   2226240.0   4018363.0   5987361.0      0.0
# 359   0          Day'Ron Sharpe   2210040.0   3989122.0   5983683.0      0.0
# 361   0  Jeremiah Robinson-Earl   1900000.0   1988598.0         0.0      0.0
# 365   0         Santiago Aldama   2194200.0   3960531.0   5940797.0      0.0
# 415   0              Herb Jones   1836096.0         0.0         0.0      0.0
# 444   0             Isaiah Todd   1836096.0   1988598.0         0.0      0.0
# 449   0                 JT Thor   1836096.0   1988598.0         0.0      0.0
# 452   0           Jason Preston   1836096.0   2295120.0         0.0      0.0
# 453   0           Isaiah Livers   1836096.0         0.0         0.0      0.0
# 456   0               BJ Boston   1836096.0   2295120.0         0.0      0.0
# 458   0    Georgios Kalaitzakis   1836096.0         0.0         0.0      0.0
# 459   0           Miles McBride   1836096.0         0.0         0.0      0.0
# 460   0              Vit Krejci   1836096.0   1988598.0         0.0      0.0
# 461   0          Charles Bassey   1836096.0         0.0         0.0      0.0
# 462   0              Greg Brown   1836096.0         0.0         0.0      0.0
# 466   0         Marko Simonovic   1836096.0         0.0         0.0      0.0
# 534   0       Demetrius Jackson     92857.0         0.0         0.0      0.0

# %%
player_salaries = player_salary[player_salary['id'] != 0].reset_index(drop = True) # exclude rookies
player_salaries.head()
# Out:
#        id       player_names     2021/22     2022/23     2023/24  2024/25
# 0  201939      Stephen Curry  51915615.0  55761217.0  59606817.0      0.0
# 1  201935       James Harden         0.0         0.0         0.0      0.0
# 2  202322          John Wall         0.0         0.0         0.0      0.0
# 3  201566  Russell Westbrook         0.0         0.0         0.0      0.0
# 4    2544       LeBron James         0.0         0.0         0.0      0.0

# %%
f = dict(Counter(player_salaries['id']))
[k for k,v in f.items() if (v > 1) | (k == 0)] # -> unique keys and only the ones with valid ID
# Out:
# []

# %%
player_salary[player_salary['player_names'] == 'Klay Thompson']
# Out:
#         id   player_names     2021/22  2022/23  2023/24  2024/25
# 10  202691  Klay Thompson  43219440.0      0.0      0.0      0.0

# %%
player_salaries.to_csv('players_salaries.csv', index = False)

# %% [markdown]
# ### Notes
#
# #### Approach:
# - Compare with list: current active players (have contract) - rookies -> für jeden active player: ID
#
# #### Alternative:
# - Basis alle Spieler, der letzten 4 Saisons
# - Contract player ids LEFT JOIN ids active past 4 seasons

# %% [markdown]
# ## Player Table & Stats

# %%
players = copy.deepcopy(player_salaries.iloc[: , :-4])
display(players.head())
print(players.shape)
# Out:
#        id       player_names
# 0  201939      Stephen Curry
# 1  201935       James Harden
# 2  202322          John Wall
# 3  201566  Russell Westbrook
# 4    2544       LeBron James
# (418, 2)

# %%
stats = []
for player in tqdm(players['id']):
    time.sleep(.600)
    call_career = playercareerstats.PlayerCareerStats(player_id=player) 
    stats.append(call_career.get_data_frames()[0])
    
stats_players = pd.concat(stats)
stats_players.head()
# Out:
# 100%|██████████| 418/418 [14:57<00:00,  2.15s/it]
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     201939   2009-10        00  1610612744               GSW        22.0
# 1     201939   2010-11        00  1610612744               GSW        23.0
# 2     201939   2011-12        00  1610612744               GSW        24.0
# 3     201939   2012-13        00  1610612744               GSW        25.0
# 4     201939   2013-14        00  1610612744               GSW        26.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  80  77  2896.0  528  ...   0.885    48   308  356  472  152   19  243  252
# 1  74  74  2489.0  505  ...   0.934    52   234  286  432  109   20  226  233
# 2  26  23   732.0  145  ...   0.809    15    73   88  138   39    8   65   62
# 3  78  78  2983.0  626  ...   0.900    59   255  314  539  126   12  240  198
# 4  78  78  2846.0  652  ...   0.885    46   288  334  666  128   14  294  194
#
#     PTS
# 0  1399
# 1  1373
# 2   383
# 3  1786
# 4  1873
#
# [5 rows x 27 columns]

# %%
stats_players.to_csv('playercareerstats.csv', index = False)

# %%
stats_players = pd.read_csv('playercareerstats.csv')

# %%
stats_players = stats_players[(stats_players['SEASON_ID'] == '2020-21') | (stats_players['SEASON_ID'] == '2019-20') | (stats_players['SEASON_ID'] == '2018-19')].reset_index().drop(columns=['index'])

# %%
print(stats_players.columns)
# Out:
# Index(['PLAYER_ID', 'SEASON_ID', 'LEAGUE_ID', 'TEAM_ID', 'TEAM_ABBREVIATION',
#        'PLAYER_AGE', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
def combine_seasons(player_id):
    df = stats_players[stats_players['PLAYER_ID'] == player_id]
    
    season_20 = df[df['SEASON_ID'] == '2020-21']
    if season_20.shape[0] == 0:
        season_20 = pd.DataFrame(np.zeros((1, len(df.columns) -6)))
    elif season_20.shape[0] > 1:
        season_20 = season_20[season_20['TEAM_ABBREVIATION'] == 'TOT'].iloc[:,6:] * 1/2
    else:
        season_20 = season_20.iloc[:,6:] * 1/2
   # except:
   #     season_20 = pd.DataFrame(np.zeros((1, len(df.columns) -6)))
    
    season_19 = df[df['SEASON_ID'] == '2019-20']
    if season_19.shape[0] == 0:
        season_19 = pd.DataFrame(np.zeros((1, len(df.columns) -6)))
    elif season_19.shape[0] > 1:
        season_19 = season_19[season_19['TEAM_ABBREVIATION'] == 'TOT'].iloc[:,6:] * 2/6
    else:
        season_19 = season_19.iloc[:,6:] * 2/6
    
    #season_19 = pd.DataFrame(np.zeros((1, len(df.columns) -6)))
    
    season_18 = df[df['SEASON_ID'] == '2018-19']
    if season_18.shape[0]  == 0:
        season_18 = pd.DataFrame(np.zeros((1, len(df.columns) -6)))
    elif season_18.shape[0] > 1:
        season_18 = season_18[season_18['TEAM_ABBREVIATION'] == 'TOT'].iloc[:,6:] * 1/6
    else:
        season_18 = season_18.iloc[:,6:] * 1/6
    #except:
    #    season_18 = pd.DataFrame(np.zeros((1, len(df.columns) -6)))
    
    values_pastSeasons = (season_20.values + season_19.values + season_18.values).flatten()
    
    if sum(values_pastSeasons) == 0:
        player_name = list(players[players['id'] == player_id]['player_names'])[0]
        print(f'No game data: {player_name} with id {player_id}')
        return 'NA'
    
    df_final = copy.deepcopy(df)
    df_final.iloc[0, 6:] = values_pastSeasons

    df_final.iloc[0, 1] = 'aggregated'
    #df_final.iloc[0, 4] = 'NA'
     
    dict_final = dict(df_final.iloc[0])
    return dict_final #pd.DataFrame.from_dict(list(r.values()), orient='index', columns = list(r.keys()))

# combine_seasons(201935)

# %%
stats_players_agg = [combine_seasons(player_id) for player_id in players['id']]
ind_player_drop = stats_players_agg.index('NA')
stats_players_agg = [x for x in stats_players_agg if x != 'NA']
stats_players_agg = pd.DataFrame(stats_players_agg)
stats_players_agg
# Out:
# No game data: Omer Yurtseven with id 1630209
#      PLAYER_ID   SEASON_ID  LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  \
# 0       201939  aggregated          0  1610612744               GSW
# 1       201935  aggregated          0  1610612745               HOU
# 2       202322  aggregated          0  1610612764               WAS
# 3       201566  aggregated          0  1610612760               OKC
# 4         2544  aggregated          0  1610612747               LAL
# ..         ...         ...        ...         ...               ...
# 412    1629719  aggregated          0  1610612747               LAL
# 413    1630238  aggregated          0  1610612746               LAC
# 414    1630235  aggregated          0  1610612762               UTA
# 415    1630216  aggregated          0  1610612764               WAS
# 416    1628539  aggregated          0  1610612744               GSW
#
#      PLAYER_AGE         GP         GS          MIN         FGM  ...    FT_PCT  \
# 0          31.0  44.666667  44.666667  1510.833333  445.333333  ...  0.944000
# 1          29.0  57.666667  57.166667  2110.000000  535.500000  ...  0.865333
# 2          28.0  25.333333  25.333333   828.000000  187.333333  ...  0.490667
# 3          30.0  63.666667  63.666667  2305.666667  578.333333  ...  0.691667
# 4          34.0  54.000000  54.000000  1846.833333  518.333333  ...  0.690833
# ..          ...        ...        ...          ...         ...  ...       ...
# 412        23.0  10.333333   0.500000    52.000000    9.500000  ...  0.227500
# 413        23.0   1.500000   0.000000     5.500000    0.500000  ...  0.000000
# 414        23.0  15.000000   0.000000   151.000000   16.000000  ...  0.500000
# 415        23.0  11.000000   0.000000    49.000000    7.000000  ...  0.416500
# 416        26.0  32.333333   4.000000   451.000000   68.166667  ...  0.568000
#
#            OREB        DREB         REB         AST        STL        BLK  \
# 0     23.333333  219.333333  242.666667  252.666667  55.500000   8.833333
# 1     51.833333  357.166667  409.000000  505.833333  94.500000  46.166667
# 2     11.000000   72.833333   83.833333  184.000000  29.166667  20.333333
# 3    106.000000  553.833333  659.833333  645.833333  99.166667  23.666667
# 4     46.000000  379.500000  425.500000  478.666667  62.000000  30.000000
# ..          ...         ...         ...         ...        ...        ...
# 412    6.666667   11.000000   17.666667    0.833333   2.500000   2.000000
# 413    0.000000    1.500000    1.500000    0.000000   0.000000   0.000000
# 414    5.500000   16.500000   22.000000   22.500000   4.500000   2.000000
# 415    0.000000    4.500000    4.500000    6.000000   1.000000   0.500000
# 416    5.000000   32.666667   37.666667   15.666667   6.666667   6.333333
#
#             TOV          PF          PTS
# 0    143.833333   90.833333  1355.666667
# 1    255.666667  165.833333  1789.500000
# 2     90.666667   34.833333   522.000000
# 3    295.166667  202.500000  1519.333333
# 4    203.833333   90.000000  1379.833333
# ..          ...         ...          ...
# 412    2.500000    4.000000    21.500000
# 413    0.000000    1.500000     1.500000
# 414   10.500000   11.000000    44.000000
# 415    2.500000    4.000000    20.500000
# 416    9.666667   34.666667   194.166667
#
# [417 rows x 27 columns]

# %%
stats_players_agg.to_csv('playercareerstats_agg.csv', index = False)

# %%
# update players_list
print(players.shape)
#players = players[players['id'] != 1630209].reset_index(drop = True)
players = players.drop(ind_player_drop).reset_index(drop = True)
print(players.shape)
# Out:
# (418, 2)
# (417, 2)

# %% [markdown]
# ### Add position

# %%
def adj_position(pos):
    if pos[0] in ['C', 'F', 'G']:
        return pos[0]
    else:
        print('Please enter a valid position.')
        pass

# %%
# add positions of players
positions_raw = []
for p_id in tqdm(players['id']):
    time.sleep(.600)
    positions_raw.append(commonplayerinfo.CommonPlayerInfo(p_id).get_data_frames()[0]['POSITION'][0])
print(len(positions_raw))

positions = [adj_position(position) for position in positions_raw]
Counter(positions)
# Out:
# 100%|██████████| 417/417 [07:22<00:00,  1.06s/it]
# 417
# Counter({'G': 200, 'F': 165, 'C': 52})

# %%
players['position'] = positions

# %%
players.head()
# Out:
#        id       player_names position
# 0  201939      Stephen Curry        G
# 1  201935       James Harden        G
# 2  202322          John Wall        G
# 3  201566  Russell Westbrook        G
# 4    2544       LeBron James        F

# %% [markdown]
# ### Add team from end of last season they played

# %%
teams_players = []
for i in range(len(players)):
    id_player = players['id'][i]
   
    teams = list(stats_players[(stats_players['PLAYER_ID'] == id_player) & (stats_players['SEASON_ID'] == '2020-21')]['TEAM_ABBREVIATION'])
    try:
        if teams[-1] == 'TOT':
            teams_players.append(teams[-2])
        else:
            teams_players.append(teams[-1])
            
    except IndexError:
        #print(players['player_names'][i], players['id'][i])
        
        teams = list(stats_players[(stats_players['PLAYER_ID'] == id_player) & (stats_players['SEASON_ID'] == '2019-20')]['TEAM_ABBREVIATION'])
        try:
            if teams[-1] == 'TOT':
                teams_players.append(teams[-2])
            else:
                teams_players.append(teams[-1])
                
        except IndexError:
            teams = list(stats_players[(stats_players['PLAYER_ID'] == id_player) & (stats_players['SEASON_ID'] == '2018-19')]['TEAM_ABBREVIATION'])
            try:
                if teams[-1] == 'TOT':
                    teams_players.append(teams[-2])
                else:
                    teams_players.append(teams[-1])
                    
            except IndexError:
                print(f"No team in the last three seasons could be found for {players['player_names'][i]} with id {players['id'][i]}")
            
            
# letzes aktives team

# %%
players['team'] = teams_players
display(players.head())
# Out:
#        id       player_names position team
# 0  201939      Stephen Curry        G  GSW
# 1  201935       James Harden        G  BKN
# 2  202322          John Wall        G  HOU
# 3  201566  Russell Westbrook        G  WAS
# 4    2544       LeBron James        F  LAL

# %%
players.to_csv('players_data.csv', index = False)
